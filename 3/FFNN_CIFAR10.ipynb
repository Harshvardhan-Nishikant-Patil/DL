# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
model = Sequential([
    Flatten(input_shape=(32, 32, 3)),
    Dense(256, activation='relu'),
    BatchNormalization(),  # Add BatchNormalization to improve training stability
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, epochs=20, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.7303 - accuracy: 0.3829 - val_loss: 1.8760 - val_accuracy: 0.3405
# Epoch 2/20
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.5578 - accuracy: 0.4439 - val_loss: 1.8162 - val_accuracy: 0.3666
# Epoch 3/20
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.4846 - accuracy: 0.4714 - val_loss: 1.5544 - val_accuracy: 0.4436
# Epoch 4/20
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.4353 - accuracy: 0.4893 - val_loss: 1.5080 - val_accuracy: 0.4694
# Epoch 5/20
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3924 - accuracy: 0.5071 - val_loss: 1.5517 - val_accuracy: 0.4404
# Epoch 6/20
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3695 - accuracy: 0.5107 - val_loss: 1.5327 - val_accuracy: 0.4559
# Epoch 7/20
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.3317 - accuracy: 0.5255 - val_loss: 1.5035 - val_accuracy: 0.4676
# Epoch 8/20
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.3120 - accuracy: 0.5329 - val_loss: 1.4664 - val_accuracy: 0.4837
# Epoch 9/20
# 1563/1563 [==============================] - 21s 14ms/step - loss: 1.2941 - accuracy: 0.5388 - val_loss: 1.4705 - val_accuracy: 0.4782
# Epoch 10/20
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.2753 - accuracy: 0.5445 - val_loss: 1.4369 - val_accuracy: 0.4869
# Epoch 11/20
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.2523 - accuracy: 0.5545 - val_loss: 1.3932 - val_accuracy: 0.5058
# Epoch 12/20
# 1563/1563 [==============================] - 19s 12ms/step - loss: 1.2445 - accuracy: 0.5562 - val_loss: 1.4279 - val_accuracy: 0.4916
# Epoch 13/20
# 1563/1563 [==============================] - 23s 15ms/step - loss: 1.2339 - accuracy: 0.5582 - val_loss: 1.3770 - val_accuracy: 0.5092
# Epoch 14/20
# 1563/1563 [==============================] - 26s 17ms/step - loss: 1.2121 - accuracy: 0.5686 - val_loss: 1.4263 - val_accuracy: 0.4975
# Epoch 15/20
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.1994 - accuracy: 0.5716 - val_loss: 1.4876 - val_accuracy: 0.4853
# Epoch 16/20
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.1886 - accuracy: 0.5780 - val_loss: 1.3893 - val_accuracy: 0.5092
# Epoch 17/20
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.1772 - accuracy: 0.5797 - val_loss: 1.4520 - val_accuracy: 0.4852
# Epoch 18/20
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.1674 - accuracy: 0.5840 - val_loss: 1.5051 - val_accuracy: 0.4786
# Epoch 19/20
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.1559 - accuracy: 0.5884 - val_loss: 1.5228 - val_accuracy: 0.4735
# Epoch 20/20
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.1501 - accuracy: 0.5891 - val_loss: 1.4418 - val_accuracy: 0.4989

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.4418 - accuracy: 0.4989
# Test accuracy: 0.49889999628067017

# %%
plt.plot(history.history['accuracy'])

# %%
plt.plot(history.history['loss'])
